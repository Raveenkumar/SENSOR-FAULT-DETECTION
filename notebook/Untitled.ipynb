# %%
# Load the newly uploaded file to inspect its structure
import pandas as pd
final_file_path = r"C:\Users\RAVEEN\Downloads\final_prediction_file.csv"
final_df = pd.read_csv(final_file_path)
final_df.drop(columns=['Wafer'],inplace=True)

# Display the first few rows and summary statistics to understand the data distribution
final_df.head(), final_df.describe()
# Out:
# (   Sensor-1  Sensor-2   Sensor-3   Sensor-4  Sensor-5  Sensor-6  Sensor-7  \
#  0   3045.98   2544.85  2253.3444  1873.8678    1.1691     100.0   94.9722
#  1   3151.98   2563.75  2175.2556  1022.1660    1.2833     100.0  100.6222
#  2   3071.18   2489.86  2195.3000  1151.8233    0.9220     100.0  103.5467
#  3   2958.46   2523.78  2171.8556  1156.6018    1.4025     100.0  100.1367
#  4   3196.21   2413.39  2255.5222  1763.0739    1.2226     100.0  101.5878
#
#     Sensor-8  Sensor-9  Sensor-10  ...  Sensor-582  Sensor-583  Sensor-584  \
#  0    0.1210    1.4752     0.0084  ...         NaN      0.4948      0.0123
#  1    0.1250    1.4536    -0.0110  ...         NaN      0.5063      0.0113
#  2    0.1232    1.4826     0.0136  ...         NaN      0.5033      0.0112
#  3    0.1243    1.4645     0.0001  ...         NaN      0.4954      0.0136
#  4    0.1200    1.4845    -0.0037  ...    353.8319      0.5058      0.0094
#
# ...

# %%
final_df.shape
# Out:
# (837, 591)

# %%
df_shape = (100,591)
import numpy as np
# Define the number of synthetic files to create
num_synthetic_files = 17

# Extract column statistics for mean and standard deviation
column_means = final_df.mean()
column_stds = final_df.std()

# Prepare a balanced 'Output' column with equal numbers of 0s and 1s
balanced_output = np.concatenate([np.ones(50), np.zeros(50)])  # 837 rows total
np.random.shuffle(balanced_output)

# Generate synthetic data and save to CSV files
synthetic_file_paths = []
for i in range(num_synthetic_files):
    # Generate synthetic data for each sensor column based on the mean and std
    synthetic_data = np.random.normal(loc=column_means, scale=column_stds, size=df_shape)
    
    # Create a DataFrame from the synthetic data
    synthetic_df = pd.DataFrame(synthetic_data, columns=final_df.columns)
    
    # Ensure the 'Output' column is balanced
    synthetic_df['Output'] = balanced_output
    
    # Save the synthetic DataFrame to a CSV file
    file_path = f'E:/data science/Projects/SENSOR-FAULT-DETECTION/db_folder_structure/testing datasets/training_datasets/wafer_150{i+1}2023_122518.csv'
    synthetic_df.to_csv(file_path, index=False)
    synthetic_file_paths.append(file_path)

# Return the list of generated file paths
synthetic_file_paths
# Out:
# ['E:/data science/Projects/SENSOR-FAULT-DETECTION/db_folder_structure/testing datasets/training_datasets/wafer_15012023_122518.csv',
#  'E:/data science/Projects/SENSOR-FAULT-DETECTION/db_folder_structure/testing datasets/training_datasets/wafer_15022023_122518.csv',
#  'E:/data science/Projects/SENSOR-FAULT-DETECTION/db_folder_structure/testing datasets/training_datasets/wafer_15032023_122518.csv',
#  'E:/data science/Projects/SENSOR-FAULT-DETECTION/db_folder_structure/testing datasets/training_datasets/wafer_15042023_122518.csv',
#  'E:/data science/Projects/SENSOR-FAULT-DETECTION/db_folder_structure/testing datasets/training_datasets/wafer_15052023_122518.csv',
#  'E:/data science/Projects/SENSOR-FAULT-DETECTION/db_folder_structure/testing datasets/training_datasets/wafer_15062023_122518.csv',
#  'E:/data science/Projects/SENSOR-FAULT-DETECTION/db_folder_structure/testing datasets/training_datasets/wafer_15072023_122518.csv',
# ...

# %%
columns_list = list(final_df.columns)
columns_list.insert(0,"Unnamed: 0")
columns_list
# Out:
# ['Unnamed: 0',
#  'Wafer',
#  'Sensor-1',
#  'Sensor-2',
#  'Sensor-3',
#  'Sensor-4',
#  'Sensor-5',
#  'Sensor-6',
#  'Sensor-7',
#  'Sensor-8',
#  'Sensor-9',
#  'Sensor-10',
#  'Sensor-11',
#  'Sensor-12',
#  'Sensor-13',
#  'Sensor-14',
#  'Sensor-15',
#  'Sensor-16',
#  'Sensor-17',
#  'Sensor-18',
#  'Sensor-19',
#  'Sensor-20',
#  'Sensor-21',
#  'Sensor-22',
#  'Sensor-23',
#  'Sensor-24',
#  'Sensor-25',
#  'Sensor-26',
#  'Sensor-27',
#  'Sensor-28',
#  'Sensor-29',
#  'Sensor-30',
#  'Sensor-31',
#  'Sensor-32',
#  'Sensor-33',
#  'Sensor-34',
#  'Sensor-35',
#  'Sensor-36',
#  'Sensor-37',
#  'Sensor-38',
#  'Sensor-39',
#  'Sensor-40',
#  'Sensor-41',
#  'Sensor-42',
#  'Sensor-43',
#  'Sensor-44',
#  'Sensor-45',
#  'Sensor-46',
#  'Sensor-47',
#  'Sensor-48',
#  'Sensor-49',
#  'Sensor-50',
#  'Sensor-51',
#  'Sensor-52',
#  'Sensor-53',
#  'Sensor-54',
#  'Sensor-55',
#  'Sensor-56',
#  'Sensor-57',
#  'Sensor-58',
#  'Sensor-59',
#  'Sensor-60',
#  'Sensor-61',
# ...

# %%
files_directory = r"E:\data science\Projects\SENSOR-FAULT-DETECTION\db_folder_structure\testing datasets\training_datasets"

# %%
prediction_dataset_path = r"E:\data science\Projects\SENSOR-FAULT-DETECTION\db_folder_structure\testing datasets\prediction_datasets"
import os
import pandas as pd
files_directory = os.path.dirname(file_path)
start_point = 1
end_point = 101
for file in os.listdir(files_directory):
    file_path = os.path.join(files_directory,file)
    df = pd.read_csv(file_path)
    print(f"file name:{file} shape:{df.shape}")
    wafer_data = [f'Wafer-{i}' for i in range(start_point,end_point)]
    start_point = end_point
    end_point += 100
    df.rename(columns={'Output':"Good/Bad"},inplace=True)
    df_columns=list(df.columns)
    df_columns.insert(0,"Unnamed: 0")
    df["Unnamed: 0"] = pd.Series(wafer_data)
    print(df_columns)
    rearanged_df = df[df_columns]
    rearanged_df.to_csv(file_path,index=False)
    print(f"{file_path} file modified successfully!")
# Out:
# file name:wafer_150102023_122518.csv shape:(100, 591)
# ...

# %%
files_directory
# Out:
# 'E:/data science/Projects/SENSOR-FAULT-DETECTION/db_folder_structure/testing datasets/training_datasets'

# %%
import os
import pandas as pd
# files_directory = os.path.dirname(file_path)

for file in os.listdir(files_directory):
    file_path = os.path.join(files_directory,file)
    df = pd.read_csv(file_path)
    prediction_file_path = os.path.join(prediction_dataset_path,file)
    df.drop(columns=["Good/Bad"],inplace=True)
    df.to_csv(prediction_file_path,index=False)
    print(f"{prediction_file_path} file modified successfully!")
# Out:
# E:\data science\Projects\SENSOR-FAULT-DETECTION\db_folder_structure\testing datasets\prediction_datasets\wafer_150102023_122518.csv file modified successfully!
# E:\data science\Projects\SENSOR-FAULT-DETECTION\db_folder_structure\testing datasets\prediction_datasets\wafer_150112023_122518.csv file modified successfully!
# E:\data science\Projects\SENSOR-FAULT-DETECTION\db_folder_structure\testing datasets\prediction_datasets\wafer_15012023_122518.csv file modified successfully!
# E:\data science\Projects\SENSOR-FAULT-DETECTION\db_folder_structure\testing datasets\prediction_datasets\wafer_150122023_122518.csv file modified successfully!
# E:\data science\Projects\SENSOR-FAULT-DETECTION\db_folder_structure\testing datasets\prediction_datasets\wafer_150132023_122518.csv file modified successfully!
# E:\data science\Projects\SENSOR-FAULT-DETECTION\db_folder_structure\testing datasets\prediction_datasets\wafer_150142023_122518.csv file modified successfully!
# ...

# %%
df = pd.read_csv(r"E:\data science\Projects\SENSOR-FAULT-DETECTION\db_folder_structure\testing datasets\prediction_datasets\wafer_150102023_122518.csv")
df.head()
# Out:
#   Unnamed: 0 Unnamed: 0.1     Sensor-1     Sensor-2     Sensor-3     Sensor-4  \
# 0    Wafer-1      Wafer-1  2855.800413  2484.670322  2258.212927  2612.940408
# 1    Wafer-2      Wafer-2  2973.944740  2468.692504  2191.682163  2214.462503
# 2    Wafer-3      Wafer-3  3023.441395  2594.765669  2192.270352  1123.494596
# 3    Wafer-4      Wafer-4  3086.998454  2536.530738  2202.906470  1043.530867
# 4    Wafer-5      Wafer-5  3078.283419  2456.299362  2195.061597  1682.411472
#
#      Sensor-5  Sensor-6    Sensor-7  Sensor-8  ...  Sensor-581  Sensor-582  \
# 0    0.468058     100.0   91.128842  0.140611  ...    0.006017   73.564070
# 1   25.406152     100.0  103.235713  0.105194  ...    0.000238  166.740049
# 2  -73.966637     100.0  102.584748  0.136051  ...    0.006330  103.461346
# 3  139.153386     100.0  100.136569  0.130724  ...    0.004172  114.037800
# 4    1.007667     100.0  106.403112  0.127544  ...    0.007210   -3.793855
#
# ...

# %%
file_dir = r"C:\Users\RAVEEN\Downloads\test"
import os
import pandas as pd
data_list = []
for file in os.listdir(file_dir):
    file_path = os.path.join(file_dir,file)
    data = pd.read_csv(file_path)
    data_list.append(data)

# %%
df_original = pd.concat(data_list,axis=0)

# %%
df_original.shape
# Out:
# (700, 592)

# %%
df_original.columns
# Out:
# Index(['Unnamed: 0', 'Sensor-1', 'Sensor-2', 'Sensor-3', 'Sensor-4',
#        'Sensor-5', 'Sensor-6', 'Sensor-7', 'Sensor-8', 'Sensor-9',
#        ...
#        'Sensor-582', 'Sensor-583', 'Sensor-584', 'Sensor-585', 'Sensor-586',
#        'Sensor-587', 'Sensor-588', 'Sensor-589', 'Sensor-590', 'Good/Bad'],
#       dtype='object', length=592)

# %%
df_prediction = pd.read_csv(r"C:\Users\RAVEEN\Downloads\final_prediction_file (1).csv")
df_prediction.shape
# Out:
# (700, 592)

# %%
confidance_score_df = pd.read_excel(r"C:\Users\RAVEEN\Downloads\predictions (1).xlsx")
confidance_score_df.shape
# Out:
# (700, 4)

# %%
confidance_score_df.isnull().sum()
# Out:
# Wafer           0
# Output          0
# Confidence      0
# Feedback      694
# dtype: int64

# %%
confidance_score_df.shape[1]<final_df.shape[1]
# Out:
# True

# %%
confidance_score_df
# Out:
#           Wafer   Output  Confidence Feedback
# 0     Wafer-223  Working        0.95      NaN
# 1     Wafer-226  Working        0.95      NaN
# 2     Wafer-228  Working        0.96      NaN
# 3     Wafer-233  Working        0.96      NaN
# 4     Wafer-234  Working        0.93      NaN
# ..          ...      ...         ...      ...
# 695  Wafer-1696  Working        0.99      NaN
# 696  Wafer-1697  Working        1.00      NaN
# 697  Wafer-1698  Working        0.99      NaN
# 698  Wafer-1699  Working        1.00      NaN
# 699  Wafer-1700  Working        1.00      NaN
#
# [700 rows x 4 columns]

# %%
confidance_score_df['Final_output'] = np.where(pd.isna(confidance_score_df['Feedback']),confidance_score_df['Output'],confidance_score_df['Feedback'])
confidance_score_df['Final_output'] = confidance_score_df['Final_output'].map({'Working':0,'NotWorking':1})
confidance_score_df
# Out:
#           Wafer   Output  Confidence Feedback  Final_output
# 0     Wafer-223  Working        0.95      NaN           0.0
# 1     Wafer-226  Working        0.95      NaN           0.0
# 2     Wafer-228  Working        0.96      NaN           0.0
# 3     Wafer-233  Working        0.96      NaN           0.0
# 4     Wafer-234  Working        0.93      NaN           0.0
# ..          ...      ...         ...      ...           ...
# 695  Wafer-1696  Working        0.99      NaN           0.0
# 696  Wafer-1697  Working        1.00      NaN           0.0
# 697  Wafer-1698  Working        0.99      NaN           0.0
# 698  Wafer-1699  Working        1.00      NaN           0.0
# 699  Wafer-1700  Working        1.00      NaN           0.0
#
# [700 rows x 5 columns]

# %%
final_output_df = confidance_score_df[['Wafer','Final_output']]
final_output_df
# Out:
#           Wafer  Final_output
# 0     Wafer-223           0.0
# 1     Wafer-226           0.0
# 2     Wafer-228           0.0
# 3     Wafer-233           0.0
# 4     Wafer-234           0.0
# ..          ...           ...
# 695  Wafer-1696           0.0
# 696  Wafer-1697           0.0
# 697  Wafer-1698           0.0
# 698  Wafer-1699           0.0
# 699  Wafer-1700           0.0
#
# [700 rows x 2 columns]

# %%
confidance_score_df['Feedback'][0]
# Out:
# nan

# %%
confidance_score_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Wafer         700 non-null    object
#  1   Output        700 non-null    object
#  2   Confidence    700 non-null    float64
#  3   Feedback      6 non-null      object
#  4   Final_output  6 non-null      object
# dtypes: float64(1), object(4)
# memory usage: 27.5+ KB

# %%
confidance_score_df.drop(columns=['Output','Feedback'],inplace=True)

# %%
confidance_score_df.rename(columns={'Wafer':'Unnamed: 0'},inplace=True)

# %%
confidance_score_df
# Out:
#      Unnamed: 0  Confidence
# 0     Wafer-223        0.95
# 1     Wafer-226        0.95
# 2     Wafer-228        0.96
# 3     Wafer-233        0.96
# 4     Wafer-234        0.93
# ..          ...         ...
# 695  Wafer-1696        0.99
# 696  Wafer-1697        1.00
# 697  Wafer-1698        0.99
# 698  Wafer-1699        1.00
# 699  Wafer-1700        1.00
#
# [700 rows x 2 columns]

# %%
merge_df = pd.merge(df_original,confidance_score_df,on='Unnamed: 0',how='left')

# %%
df_prediction
# Out:
#           Wafer     Sensor-1     Sensor-2     Sensor-3     Sensor-4  \
# 0     Wafer-201  2833.037768  2409.451861  2216.184681   726.007972
# 1     Wafer-202  3036.738787  2472.943479  2191.579298  1357.395390
# 2     Wafer-203  3111.908623  2632.810180  2232.785921  1586.447429
# 3     Wafer-204  2965.575783  2472.261228  2227.451436  2185.588470
# 4     Wafer-205  2961.474576  2528.790903  2221.832202  1173.194302
# ..          ...          ...          ...          ...          ...
# 695  Wafer-1696  2955.724320  2597.206028  2221.960386  1668.788467
# 696  Wafer-1697  2981.582584  2472.975311  2182.054825  1053.723750
# 697  Wafer-1698  3085.084985  2483.849055  2204.034131  1893.304531
# 698  Wafer-1699  3089.573162  2439.199371  2149.229707  1716.022410
# 699  Wafer-1700  3102.928439  2455.214117  2182.746352  1280.187561
#
#        Sensor-5  Sensor-6    Sensor-7  Sensor-8  Sensor-9  ...  Sensor-582  \
# ...

# %%
df_prediction.rename(columns={'Wafer':'Unnamed: 0'},inplace=True)

df_prediction_set = df_prediction[['Unnamed: 0','Output']]
df_prediction_set
# Out:
#      Unnamed: 0  Output
# 0     Wafer-201       0
# 1     Wafer-202       0
# 2     Wafer-203       0
# 3     Wafer-204       0
# 4     Wafer-205       0
# ..          ...     ...
# 695  Wafer-1696       0
# 696  Wafer-1697       0
# 697  Wafer-1698       0
# 698  Wafer-1699       0
# 699  Wafer-1700       0
#
# [700 rows x 2 columns]

# %%
final_df = pd.merge(merge_df,df_prediction_set,on='Unnamed: 0',how='left')

result_df = final_df[['Unnamed: 0','Good/Bad','Output','Confidence']]
result_df
# Out:
#      Unnamed: 0  Good/Bad  Output  Confidence
# 0     Wafer-201       1.0       0        0.96
# 1     Wafer-202       1.0       0        1.00
# 2     Wafer-203       1.0       0        1.00
# 3     Wafer-204       1.0       0        0.99
# 4     Wafer-205       1.0       0        1.00
# ..          ...       ...     ...         ...
# 695  Wafer-1696       1.0       0        0.99
# 696  Wafer-1697       1.0       0        1.00
# 697  Wafer-1698       1.0       0        0.99
# 698  Wafer-1699       1.0       0        1.00
# 699  Wafer-1700       1.0       0        1.00
#
# [700 rows x 4 columns]

# %%
result_df[(result_df['Good/Bad']==result_df['Output']) & (result_df['Confidence']<0.75)]
# Out:
#      Unnamed: 0  Good/Bad  Output  Confidence
# 335  Wafer-1236       1.0       1        0.60
# 478  Wafer-1479       1.0       1        0.59
# 505  Wafer-1506       1.0       1        0.59
# 604  Wafer-1605       1.0       1        0.59
# 663  Wafer-1664       1.0       1        0.60
# 676  Wafer-1677       1.0       1        0.62

# %%
from sklearn.metrics import accuracy_score
import numpy as np

# %%
y_true = np.array(result_df['Good/Bad'])
y_pred = np.array(result_df['Output'])

# %%
accuracy_score(y_true,y_pred)
# Out:
# 0.49857142857142855

# %%
from src.db_management.aws_storage import SimpleStorageService
from src.entity.config_entity import S3Config
config = S3Config()
s3 = SimpleStorageService(config)

# %%
s3_resource = s3.s3_resource

# %%
# Specify your bucket name and object key
bucket_name = 'wafersensorsdata'
object_key = 'artifacts/05_10_2024_14_30_05/prediction_data/evaluation_data/data_drift_report_with_column_mapping.html'

# Generate a pre-signed URL for the file, valid for 15 days
s3_object = s3_resource.Object(bucket_name, object_key)
url = s3_object.meta.client.generate_presigned_url(
    'get_object',
    Params={'Bucket': bucket_name, 'Key': object_key},
    ExpiresIn=604799  # URL valid for 15 days
)

print(f"Your pre-signed URL is: {url}")
# Out:
# Your pre-signed URL is: https://wafersensorsdata.s3.amazonaws.com/artifacts/05_10_2024_14_30_05/prediction_data/evaluation_data/data_drift_report_with_column_mapping.html?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA6GBMECT7CKWN5RV2%2F20241005%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20241005T213540Z&X-Amz-Expires=604799&X-Amz-SignedHeaders=host&X-Amz-Signature=3c98864a8a0e72b6ddf7fe4dddc7c0b959992b88f1661b9237971b0626da6d7f

# %%
# Specify your bucket name and object key
bucket_name = 'wafersensorsdata'
object_key = 'artifacts/05_10_2024_14_30_05/prediction_data/evaluation_data/prediction_validation_logs.xlsx'

# Generate a pre-signed URL for the file, valid for 15 days
s3_object = s3_resource.Object(bucket_name, object_key)
url = s3_object.meta.client.generate_presigned_url(
    'get_object',
    Params={'Bucket': bucket_name, 'Key': object_key},
    ExpiresIn=604799  # URL valid for 15 days
)

print(f"Your pre-signed URL is: {url}")
# Out:
# Your pre-signed URL is: https://wafersensorsdata.s3.amazonaws.com/artifacts/05_10_2024_14_30_05/prediction_data/evaluation_data/prediction_validation_logs.xlsx?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA6GBMECT7CKWN5RV2%2F20241005%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20241005T221836Z&X-Amz-Expires=604799&X-Amz-SignedHeaders=host&X-Amz-Signature=0adb9ea8db5e79668de1227280f531dbc8d5408a92fa4f7402e86c71966cf479

# %%
from src.logger import logger
from src.exception import SensorFaultException

# %%
import pandas as pd
from openpyxl import load_workbook
from openpyxl.styles import Border, Side, PatternFill, Font, Alignment
from openpyxl.worksheet.datavalidation import DataValidation

# Sample dict data
data_dict = {"Wafer_id": [1, 2, 3], 
             "Working_status": ["Working", "NotWorking", "Working"], 
             "Confidance": [0.95, 0.85, 0.75]}

# Function to save model result in Excel with feedback column
def save_model_result_excel(df: pd.DataFrame, excel_file_path: str) -> None:
    """save_model_result_excel :Used for store the model results in excel file 

    Args:
        df (pd.DataFrame): DataFrame containing the model results
        excel_file_path (str): Path where the excel file will be saved
    """
    try:
        # Add the "Feedback" column with default empty values
        df['Feedback'] = ""

        # Save the DataFrame to Excel
        df.to_excel(excel_file_path, index=False, engine='openpyxl')

        # Style the Excel file and add dropdown
        style_excel(excel_file_path)
        logger.info("save_model_result_excel :: Status:created-result data added")

    except Exception as e:
        error_message = SensorFaultException(error_message=str(e), error_detail=sys)
        logger.error(f"save_model_result_excel :: Status:Failed :: Error:{error_message}")
        raise error_message


def style_excel(excel_filename: str) -> None:
    """style_excel : Used for styling the Excel file and adding feedback dropdown.

    Args:
        excel_filename (str): Path to the Excel file
    """
    wb = load_workbook(excel_filename)
    ws = wb.active

    # Define border style
    thin_border = Border(
        left=Side(style='thin'),
        right=Side(style='thin'),
        top=Side(style='thin'),
        bottom=Side(style='thin')
    )

    # Define header fill color and font style
    header_fill = PatternFill(start_color='FFFF00', end_color='FFFF00', fill_type='solid')  # Yellow color
    header_font = Font(bold=True, color='000000')  # Black color for text

    # Apply styles to the header row
    for cell in ws[1]:  # type: ignore
        cell.fill = header_fill
        cell.font = header_font
        cell.border = thin_border
        cell.alignment = Alignment(horizontal='center', vertical='center')

    # Apply border to all data cells and adjust column widths
    for row in ws.iter_rows(min_row=2, min_col=1, max_col=ws.max_column, max_row=ws.max_row):  # type: ignore
        for cell in row:
            cell.border = thin_border

    # Adjust column widths based on the maximum length of the data in each column
    for column in ws.columns:  # type: ignore
        max_length = 0
        column_letter = column[0].column_letter  # Get the column letter (e.g., 'A', 'B')
        for cell in column:
            try:
                max_length = max(max_length, len(str(cell.value)))
            except:
                pass
        adjusted_width = max_length + 2  # Add some padding
        ws.column_dimensions[column_letter].width = adjusted_width  # type: ignore

    # Add DataValidation for the "Feedback" column (Assumed to be column D in this case)
    feedback_validation = DataValidation(
        type="list", 
        formula1='"Working,NotWorking"', 
        allow_blank=True
    )
    feedback_validation.error = 'Invalid feedback'
    feedback_validation.errorTitle = 'Invalid Input'
    feedback_validation.prompt = 'Select from the list'
    feedback_validation.promptTitle = 'Feedback'

    # Assuming Feedback is the fourth column (D), apply dropdown to all rows in column D
    ws.add_data_validation(feedback_validation)
    feedback_validation.add(f'D2:D{ws.max_row}')

    # Save the styled and updated workbook
    wb.save(excel_filename)


# Sample usage
df = pd.DataFrame(data_dict)
save_model_result_excel(df, 'model_results.xlsx')
# Out:
# [2024-10-07 10:39:04,749: INFO: 1632443724: save_model_result_excel :: Status:created-result data added]

# %%
import pandas as pd
df = pd.read_excel('model_results.xlsx')
df
# Out:
#    Wafer_id Working_status  Confidance  Feedback
# 0         1        Working        0.95       NaN
# 1         2     NotWorking        0.85       NaN
# 2         3        Working        0.75       NaN

# %%
df.columns
# Out:
# Index(['Wafer_id', 'Working_status', 'Confidance', 'Feedback'], dtype='object')

# %%
# %pwd
# Out:
# 'e:\\data science\\Projects\\SENSOR-FAULT-DETECTION\\notebook'

# %%
import os
os.chdir("../")

# %%
# %pwd
# Out:
# 'e:\\data science\\Projects\\SENSOR-FAULT-DETECTION'

# %%
from src.entity.config_entity import PredictionPipelineConfig

file_path = r"C:\Users\RAVEEN\Downloads\predictions (1).xlsx"

# %%
from src.utilities.utils import send_datadrift_mail_client

# %%
send_datadrift_mail_client(file_path)
# Out:
# [2024-10-07 14:32:11,941: INFO: utils: Data Drift Email with attached file sent successfully!]
# [2024-10-07 14:32:11,942: INFO: utils: send_datadrift_mail to client :: Status:Success]

# %%
import os
os.chdir("../")

# %%
path = r"artifacts\training_batch_files"

# %%
files_list = os.listdir(path)
files_list[1].endswith("xlsx")
# Out:
# True

# %%
from src.entity.config_entity import BaseArtifactConfig
BaseArtifactConfig.artifact_dir
# Out:
# WindowsPath('artifacts/10_10_2024_02_49_02')

# %%
original = r"C:\Users\RAVEEN\Downloads\predictions (2).xlsx"
predicted = r"C:\Users\RAVEEN\Downloads\predictions (1).xlsx"

# %%
import pandas as pd
original_df = pd.read_excel(original)
predicted_df = pd.read_excel(predicted)

# %%
predicted_df.rename(columns={'Output':'Newoutput'},inplace=True)

# %%
merge_df = pd.merge(original_df,predicted_df,on='Wafer')

# %%
merge_df.drop(columns=['Feedback'],inplace=True)

# %%
merge_df['Output'] = merge_df['Output'].map({'Working':0,'NotWorking':1})
merge_df['Newoutput'] = merge_df['Newoutput'].map({'Working':0,'NotWorking':1})

# %%
merge_df.columns
# Out:
# Index(['Wafer', 'Output', 'Confidence_x', 'Newoutput', 'Confidence_y'], dtype='object')

# %%
y_true = merge_df['Confidence_x']
y_pred = merge_df['Confidence_y']

# %% [markdown]
# from sklearn.metrics import accuracy_score
# accuracy_score(y_true,y_pred)

# %%
merge_df[merge_df['Confidence_x']<0.70]
# Out:
#           Wafer  Output  Confidence_x  Newoutput  Confidence_y
# 21    Wafer-955       1          0.62          1          0.99
# 30    Wafer-989       1          0.59          1          0.96
# 39   Wafer-1117       1          0.59          1          0.98
# 48   Wafer-1167       1          0.61          1          0.99
# 58   Wafer-1236       1          0.60          1          0.98
# 67   Wafer-1428       1          0.60          1          0.95
# 79   Wafer-1479       1          0.59          1          0.99
# 84   Wafer-1506       1          0.59          1          0.91
# 99   Wafer-1605       1          0.59          1          0.99
# 105  Wafer-1638       1          0.63          1          0.99
# 107  Wafer-1657       1          0.61          1          0.97
# 108  Wafer-1664       1          0.60          1          0.94
# 111  Wafer-1677       1          0.62          1          0.97
